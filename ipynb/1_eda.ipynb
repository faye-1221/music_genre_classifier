# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
file_path = "./input/genres_v2.csv"

df = pd.read_csv(file_path, low_memory=False)

# %%
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42305 entries, 0 to 42304
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      42305 non-null  float64
#  1   energy            42305 non-null  float64
#  2   key               42305 non-null  int64
#  3   loudness          42305 non-null  float64
#  4   mode              42305 non-null  int64
#  5   speechiness       42305 non-null  float64
#  6   acousticness      42305 non-null  float64
#  7   instrumentalness  42305 non-null  float64
#  8   liveness          42305 non-null  float64
#  9   valence           42305 non-null  float64
#  10  tempo             42305 non-null  float64
#  11  type              42305 non-null  object
#  12  id                42305 non-null  object
#  13  uri               42305 non-null  object
#  14  track_href        42305 non-null  object
#  15  analysis_url      42305 non-null  object
# ...

# %%
df.iloc[0]
# Out:
# danceability                                                    0.831
# energy                                                          0.814
# key                                                                 2
# loudness                                                       -7.364
# mode                                                                1
# speechiness                                                      0.42
# acousticness                                                   0.0598
# instrumentalness                                               0.0134
# liveness                                                       0.0556
# valence                                                         0.389
# tempo                                                         156.985
# type                                                   audio_features
# id                                             2Vc6NJ9PW9gD9q343XFRKx
# ...

# %%
df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  42305.000000  42305.000000  42305.000000  42305.000000  42305.000000
# mean       0.639364      0.762516      5.370240     -6.465442      0.549462
# std        0.156617      0.183823      3.666145      2.941165      0.497553
# min        0.065100      0.000243      0.000000    -33.357000      0.000000
# 25%        0.524000      0.632000      1.000000     -8.161000      0.000000
# 50%        0.646000      0.803000      6.000000     -6.234000      1.000000
# 75%        0.766000      0.923000      9.000000     -4.513000      1.000000
# max        0.988000      1.000000     11.000000      3.148000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  42305.000000  42305.000000      42305.000000  42305.000000
# mean       0.136561      0.096160          0.283048      0.214079
# std        0.126168      0.170827          0.370791      0.175576
# ...

# %% [markdown]
# # features drop

# %%
df = df.drop(['type', 'id', 'uri', 'track_href', 'analysis_url', 'song_name', 'Unnamed: 0', 'title'], axis=1)
# df = df.drop(['key', 'mode', 'time_signature'], axis=1)

# %% [markdown]
# key, mode, time_signature가 필요할 것이라 생각되어 사용했었으나 fature Importance가 낮고, 오히려 제거 했을 때 성능이 향상되어 제거

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.013400    0.0556   0.3890  156.985       124539               4
# 1          0.000000    0.1180   0.1240  115.080       224427               4
# 2          0.000004    0.3720   0.0391  218.050        98821               4
# 3          0.000000    0.1140   0.1750  186.948       123661               3
# 4          0.000000    0.1660   0.5910  147.988       123298               4
#
#        genre
# 0  Dark Trap
# 1  Dark Trap
# 2  Dark Trap
# ...

# %%
df['genre'].unique()
# Out:
# array(['Dark Trap', 'Underground Rap', 'Trap Metal', 'Emo', 'Rap', 'RnB',
#        'Pop', 'Hiphop', 'techhouse', 'techno', 'trance', 'psytrance',
#        'trap', 'dnb', 'hardstyle'], dtype=object)

# %%
df['genre'].value_counts()
# Out:
# Underground Rap    5875
# Dark Trap          4578
# Hiphop             3028
# trance             2999
# trap               2987
# techhouse          2975
# dnb                2966
# psytrance          2961
# techno             2956
# hardstyle          2936
# RnB                2099
# Trap Metal         1956
# Rap                1848
# Emo                1680
# Pop                 461
# Name: genre, dtype: int64

# %%
sns.countplot(data=df, x='genre')
plt.title('Genre Distribution')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 데이터 불균형이 존재, Pop이 제일 적음

# %%
df.isnull().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# genre               0
# dtype: int64

# %% [markdown]
# ## 상관관계

# %% [markdown]
# https://wikidocs.net/157461
# https://ko.wikipedia.org/wiki/%EC%83%81%EA%B4%80_%EB%B6%84%EC%84%9D
#
# - r이 -1.0과 -0.7이이면, 강한 음적 선형관계
# - r이 -0.7과 -0.3 사이이면, 뚜렷한 음적 선형관계
# - r이 -0.3과 -0.1 사이이면, 약한 음적 선형관계
# - r이 -0.1과 +0.1 사이이면, 거의 무시될 수 있는 선형관계,
# - r이 +0.1과 +0.3 사이이면, 약한 양적 선형관계,
# - r이 +0.3과 +0.7 사이이면, 뚜렷한 양적 선형관계,
# - r이 +0.7과 +1.0 사이이면, 강한 양적 선형관계

# %%
df_y = df['genre']
df_x = df.drop(['genre'], axis=1)

features = list(df_x.columns)

correlation_matrix = df_x.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f')
# Out:
# <AxesSubplot: >

# %%
print(correlation_matrix[(correlation_matrix >= 0.3) & (correlation_matrix < 1.0)].stack().dropna())
print(correlation_matrix[(correlation_matrix >= -1.0) & (correlation_matrix < -0.3)].stack().dropna())
# Out:
# danceability      valence             0.369845
# energy            loudness            0.601540
#                   instrumentalness    0.303875
# loudness          energy              0.601540
# instrumentalness  energy              0.303875
#                   duration_ms         0.603784
# valence           danceability        0.369845
# duration_ms       instrumentalness    0.603784
# dtype: float64
# danceability      energy             -0.323248
# energy            danceability       -0.323248
#                   acousticness       -0.497334
# speechiness       instrumentalness   -0.386571
#                   duration_ms        -0.309892
# acousticness      energy             -0.497334
# instrumentalness  speechiness        -0.386571
# duration_ms       speechiness        -0.309892
# dtype: float64

# %% [markdown]
# 새로운 피쳐를 생성해서 성능 향상을 시도하였으나 성능이 향상되지는 않았음

# %% [markdown]
# # 분포도

# %%
n_cols = 4
n_rows = (len(features)) // n_cols + 1
fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 5 * n_rows))

for i, col in enumerate(features):
    row_idx = i // n_cols
    col_idx = i % n_cols
    sns.barplot(data=df_x, x=df_y, y=col, ax=axes[row_idx, col_idx])
    axes[row_idx, col_idx].set_xticklabels(axes[row_idx, col_idx].get_xticklabels(), rotation=90)

for j in range(i + 1, n_rows * n_cols):
    fig.delaxes(axes[j // n_cols, j % n_cols])

plt.tight_layout()
plt.show()

# %%
for feat in features:
    sns.kdeplot(data=df, x=feat, hue='genre', fill=True)
    plt.title(f'{feat} Distribution by Genre')
    plt.show()

# %% [markdown]
# Underground Rap의 경우 전반적으로 넓게 분포되어 있으며며 유독 해당 클래스가 잘 잡히지 않았음

# %% [markdown]
# # box plot

# %%
plt.figure(figsize=(12, 8))

for col in features:
    sns.boxplot(x='genre', y=col, data=df)
    plt.title(f'{col} by Genre')
    plt.xticks(rotation=90)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 정규성 검정

# %%
from scipy.stats import shapiro

# %%
df_x = df.drop(['genre'], axis=1)

# %%
for col in df_x.columns:
    stat, p_value = shapiro(df_x[col].dropna())
    print(f"{col}-stat={stat:.3f}, p-value={p_value}")

    if p_value <= 0.05:
        print(f"{col} 은(는) 정규성 불만족.")
# Out:
# danceability-stat=0.987, p-value=0.0
# danceability 은(는) 정규성 불만족.
# energy-stat=0.928, p-value=0.0
# energy 은(는) 정규성 불만족.
# key-stat=0.913, p-value=0.0
# key 은(는) 정규성 불만족.
# loudness-stat=0.979, p-value=0.0
# loudness 은(는) 정규성 불만족.
# mode-stat=0.633, p-value=0.0
# mode 은(는) 정규성 불만족.
# speechiness-stat=0.777, p-value=0.0
# speechiness 은(는) 정규성 불만족.
# acousticness-stat=0.618, p-value=0.0
# acousticness 은(는) 정규성 불만족.
# instrumentalness-stat=0.709, p-value=0.0
# instrumentalness 은(는) 정규성 불만족.
# liveness-stat=0.788, p-value=0.0
# liveness 은(는) 정규성 불만족.
# valence-stat=0.949, p-value=0.0
# valence 은(는) 정규성 불만족.
# tempo-stat=0.970, p-value=0.0
# tempo 은(는) 정규성 불만족.
# duration_ms-stat=0.928, p-value=0.0
# duration_ms 은(는) 정규성 불만족.
# time_signature-stat=0.217, p-value=0.0
# time_signature 은(는) 정규성 불만족.
